# %%
import geojson

# %%
countries = geojson.load(countries.geojson)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-533d38dbe391> in <module>
# ----> 1 countries = geojson.load(countries.geojson)
#
# NameError: name 'countries' is not defined

# %%
import json

with open('countries.geojson') as f:
    data = json.load(f)

for feature in data['features']:
    print(feature['properties']['ADMIN'])
    print(feature['geometry']['type'])
    print(feature['geometry']['coordinates'][0])
# Out:
# Aruba
# Polygon
# ...

# %%
import pandas

# %%
country_list = []
coordinates_list = []
shape_type_list = []

# %%
import json

with open('countries.geojson') as f:
    data = json.load(f)

for feature in data['features']:
    if feature['geometry']['type'] == 'Polygon':
        country = feature['properties']['ADMIN']
        country_list.append(country)
        shape_type = feature['geometry']['type']
        shape_type_list.append(shape_type)
        coordinates = feature['geometry']['coordinates']
        coordinates_list.append(coordinates)
    else:
        country = feature['properties']['ADMIN']
        print(f'{country} not compatible')
# Out:
# Angola not compatible
# Anguilla not compatible
# Aland not compatible
# United Arab Emirates not compatible
# Argentina not compatible
# Armenia not compatible
# American Samoa not compatible
# Antarctica not compatible
# French Southern and Antarctic Lands not compatible
# Antigua and Barbuda not compatible
# Australia not compatible
# Azerbaijan not compatible
# Bangladesh not compatible
# The Bahamas not compatible
# Belize not compatible
# Bermuda not compatible
# Brazil not compatible
# Brunei not compatible
# Canada not compatible
# Chile not compatible
# China not compatible
# Ivory Coast not compatible
# Cyprus No Mans Area not compatible
# Democratic Republic of the Congo not compatible
# Cook Islands not compatible
# Colombia not compatible
# Comoros not compatible
# Cape Verde not compatible
# Costa Rica not compatible
# Cuba not compatible
# Cayman Islands not compatible
# Northern Cyprus not compatible
# Cyprus not compatible
# Germany not compatible
# ...

# %%
country_list
# Out:
# ['Aruba',
#  'Afghanistan',
#  'Albania',
#  'Andorra',
#  'Ashmore and Cartier Islands',
#  'Austria',
#  'Burundi',
#  'Belgium',
#  'Benin',
#  'Burkina Faso',
#  'Bulgaria',
#  'Bahrain',
#  'Bosnia and Herzegovina',
#  'Bajo Nuevo Bank (Petrel Is.)',
#  'Saint Barthelemy',
#  'Belarus',
#  'Bolivia',
#  'Barbados',
#  'Bhutan',
#  'Botswana',
#  'Central African Republic',
#  'Switzerland',
#  'Clipperton Island',
#  'Cameroon',
#  'Republic of Congo',
#  'Coral Sea Islands',
#  'Cura̤ao',
#  'Czech Republic',
#  'Djibouti',
#  'Dominica',
#  'Algeria',
#  'Dhekelia Sovereign Base Area',
#  'Ethiopia',
#  'Georgia',
#  'Ghana',
#  'Gibraltar',
#  'Guinea',
#  'Gambia',
#  'Guatemala',
#  'Guam',
#  'Heard Island and McDonald Islands',
#  'Hungary',
#  'Isle of Man',
#  'Iraq',
#  'Israel',
#  'Jamaica',
#  'Jersey',
#  'Jordan',
#  'Baykonur Cosmodrome',
#  'Siachen Glacier',
#  'Kyrgyzstan',
#  'Kosovo',
#  'Laos',
#  'Lebanon',
#  'Liberia',
#  'Libya',
#  'Saint Lucia',
# ...

# %%
shape_type_list
# Out:
# ['Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
#  'Polygon',
# ...

# %%
len(coordinates_list[2])
# Out:
# 3

# %%
country_shape_df
# Out:
#                          0
# Polygon              Aruba
# Polygon        Afghanistan
# MultiPolygon        Angola
# MultiPolygon      Anguilla
# Polygon            Albania
# ...                    ...
# MultiPolygon         Samoa
# MultiPolygon         Yemen
# MultiPolygon  South Africa
# Polygon             Zambia
# Polygon           Zimbabwe
#
# [255 rows x 1 columns]

# %%
np.shape(country_list)
# Out:
# (255,)

# %%
np.shape(type_list)
# Out:
# (255,)

# %%
np.shape(coordinates_list)
# Out:
# C:\Users\nikoe\anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# (255,)

# %%
import pandas as pd

# %%
country = pd.DataFrame(country_list, type_list, coordinates_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-4cd08530ef54> in <module>
# ----> 1 country = pd.DataFrame(country_list, type_list, coordinates_list)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     582                     mgr = arrays_to_mgr(arrays, columns, index, columns, dtype=dtype)
#     583                 else:
# --> 584                     mgr = init_ndarray(data, index, columns, dtype=dtype, copy=copy)
#     585             else:
#     586                 mgr = init_dict({}, index, columns, dtype=dtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_ndarray(values, index, columns, dtype, copy)
#     204
#     205     # _prep_ndarray ensures that values.ndim == 2 at this point
# --> 206     index, columns = _get_axes(
# ...
